# %%
from pathlib import Path
import dask.dataframe as dd
import pandas as pd

import config

# settings 
pd.set_option('display.max_columns', 110) # 110 is the number of columns in the dataset
pd.set_option('display.max_rows', 1000)

# Path to the data directory
base_data_dir = Path('data') 
players_csv_path = base_data_dir / 'players.csv'

# Read the data
players_df = pd.read_csv(players_csv_path, usecols=config.TARGET_COLS)

# %%
players_df.columns.to_list()

# %%
players_df.head()
